# %%
import pandas as pd

# %%
df_N1_N = pd.read_pickle('./filtered_N1_N.pkl')

# %%
# filter where year_N is 1989 onwards
df_1989_onwards = df_N1_N[df_N1_N['year_N'] >= 1989]

df_1989_onwards["HS_N"].astype(str).str.len().value_counts()
# Out:
# HS_N
# 8    463834
# Name: count, dtype: int64
